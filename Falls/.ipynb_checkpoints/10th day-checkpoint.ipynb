# %% [markdown]
# # 19th May

# %%
import tweepy
import pandas as pd
import numpy as np
import re
import seaborn as sns
import matplotlib.pyplot as plt
from textblob import TextBlob
from tweepy.auth import OAuthHandler

# %%
path = r'/home/edmundotome/Documents/Github Projects/LogAPItwitter.csv'
log = pd.read_csv(path)

# %%
consumerKey = log['API Key'][0]
consumerSecret = log['API Key Secret'][0]

accessToken = log['Access Token'][0]
accessTokenSecret = log['Access Token Secret'][0]

# %%
auth = OAuthHandler(consumerKey, consumerSecret)
auth.set_access_token(accessToken, accessTokenSecret)

api = tweepy.API(auth, wait_on_rate_limit=True)

# %%
#gather 1000 tweets about Bitcoin and filter out any retweets 'RT'
search_term = '#bitcoin -filter:retweets'

#create a cursor object
tweets = tweepy.Cursor(api.search, q=search_term, lang='en', since='2021-05-19', tweet_mode='extended').items(1000)

#store tweets in a variable and get the full text
all_tweets = [tweet.full_text for tweet in tweets]

# %%
#create a dataframe to store the tweets with a column called 'tweets'
df = pd.DataFrame(all_tweets, columns=['Tweets'])
#show the first 5 rows of data
df.head(10)
# Out:
#                                               Tweets
# 0  [NEW] Monthly Skeptics Discussion - January 20...
# 1  #Bitcoin attacking the H1 EMA30 again.\nIt has...
# 2  @WatcherGuru Someone please explain in simple ...
# 3  Our trading bots just closed a signal for BNBE...
# 4  #Bitcoin attacking the H1 EMA30 again.\nIt has...
# 5  Our trading bots just closed a signal for OMGB...
# 6  @BluesparrowC @CoinMarketCap @BlueSparrowETH #...
# 7  💰 CRYPTO BUYS (01/17/2022 01:01)\n- Internet C...
# 8  💰 CRYPTO BUYS (01/17/2022 01:01)\n- THORChain:...
# 9  Our trading bots just closed a signal for BNBB...

# %%
#create a function to clean the tweets 
def cleanTwt(twt):
  twt = re.sub('#bitcoin', 'bitcoin', twt) #removes the '#' from bitcoin
  twt = re.sub('#Bitcoin', 'Bitcoin', twt)
  twt = re.sub('#BTC', 'Bitcoin', twt)
  twt = re.sub('#[A-Za-z0-9]+', '', twt) #removes any strings with a '#'
  twt = re.sub('\\n', '', twt) #removes the '\n' string
  twt = re.sub('https?:\/\/\S+', '', twt) #removes any hyperlinks
  return twt

# %%
#clean the tweets
df['Cleaned Tweets'] = df['Tweets'].apply(cleanTwt)
#show the dataset
df.head()
# Out:
#                                               Tweets  \
# 0  [NEW] Monthly Skeptics Discussion - January 20...
# 1  #Bitcoin attacking the H1 EMA30 again.\nIt has...
# 2  @WatcherGuru Someone please explain in simple ...
# 3  Our trading bots just closed a signal for BNBE...
# 4  #Bitcoin attacking the H1 EMA30 again.\nIt has...
#
#                                       Cleaned Tweets
# 0  [NEW] Monthly Skeptics Discussion - January 20...
# 1  Bitcoin attacking the H1 EMA30 again.It has be...
# 2  @WatcherGuru Someone please explain in simple ...
# 3  Our trading bots just closed a signal for BNBE...
# 4  Bitcoin attacking the H1 EMA30 again.It has be...

# %%
#create a function to get subjetivity
def getSubjectivity(twt):
  return TextBlob(twt).sentiment.subjectivity
#create a function to get polarity
def getPolarity(twt):
  return TextBlob(twt).sentiment.polarity

#create two new columns called 'Subjetivity' and 'Polarity'
df['Subjetivity'] = df['Cleaned Tweets'].apply(getSubjectivity)

df['Polarity'] = df['Cleaned Tweets'].apply(getPolarity)

df.head(15)
# Out:
#                                                Tweets  \
# 0   [NEW] Monthly Skeptics Discussion - January 20...
# 1   #Bitcoin attacking the H1 EMA30 again.\nIt has...
# 2   @WatcherGuru Someone please explain in simple ...
# 3   Our trading bots just closed a signal for BNBE...
# 4   #Bitcoin attacking the H1 EMA30 again.\nIt has...
# 5   Our trading bots just closed a signal for OMGB...
# 6   @BluesparrowC @CoinMarketCap @BlueSparrowETH #...
# 7   💰 CRYPTO BUYS (01/17/2022 01:01)\n- Internet C...
# 8   💰 CRYPTO BUYS (01/17/2022 01:01)\n- THORChain:...
# 9   Our trading bots just closed a signal for BNBB...
# 10  #Bitcoin attacking the H1 EMA30 again.\nIt has...
# 11  Our trading bots just closed a signal for OMGU...
# 12  Our eyes on $ADA... • Price (#USD): $ 1.495000...
# 13  Wealth of world's 10 richest men doubled in pa...
# 14  #Bitcoin attacking the H1 EMA30 again.\nIt has...
#
#                                        Cleaned Tweets  Subjetivity  Polarity
# 0   [NEW] Monthly Skeptics Discussion - January 20...     0.454545  0.136364
# 1   Bitcoin attacking the H1 EMA30 again.It has be...     0.393750 -0.156250
# 2   @WatcherGuru Someone please explain in simple ...     0.357143  0.000000
# 3   Our trading bots just closed a signal for BNBE...     0.100000 -0.100000
# 4   Bitcoin attacking the H1 EMA30 again.It has be...     0.393750 -0.156250
# 5   Our trading bots just closed a signal for OMGB...     0.100000 -0.100000
# 6   @BluesparrowC @CoinMarketCap @BlueSparrowETH  ...     0.300000  0.200000
# 7   💰 CRYPTO BUYS (01/17/2022 01:01)- Internet Com...     0.000000  0.000000
# 8   💰 CRYPTO BUYS (01/17/2022 01:01)- THORChain: $...     0.000000  0.000000
# 9   Our trading bots just closed a signal for BNBB...     0.100000 -0.100000
# 10  Bitcoin attacking the H1 EMA30 again.It has be...     0.393750 -0.156250
# 11  Our trading bots just closed a signal for OMGU...     0.100000 -0.100000
# 12  Our eyes on $ADA... • Price (): $ 1.49500000  ...     0.000000  0.000000
# 13  Wealth of world's 10 richest men doubled in pa...     0.000000  0.000000
# 14  Bitcoin attacking the H1 EMA30 again.It has be...     0.393750 -0.156250

# %%
#create a function to get sentiment text 
def getSentiment(score):
  if score < 0:
    return 'Negative'
  elif score == 0:
    return 'Neutral'
  else:
    return 'Positive'

# %%
#create a column to store the text sentiment
df['Sentiment'] = df['Polarity'].apply(getSentiment)

df.head(15)
# Out:
#                                                Tweets  \
# 0   [NEW] Monthly Skeptics Discussion - January 20...
# 1   #Bitcoin attacking the H1 EMA30 again.\nIt has...
# 2   @WatcherGuru Someone please explain in simple ...
# 3   Our trading bots just closed a signal for BNBE...
# 4   #Bitcoin attacking the H1 EMA30 again.\nIt has...
# 5   Our trading bots just closed a signal for OMGB...
# 6   @BluesparrowC @CoinMarketCap @BlueSparrowETH #...
# 7   💰 CRYPTO BUYS (01/17/2022 01:01)\n- Internet C...
# 8   💰 CRYPTO BUYS (01/17/2022 01:01)\n- THORChain:...
# 9   Our trading bots just closed a signal for BNBB...
# 10  #Bitcoin attacking the H1 EMA30 again.\nIt has...
# 11  Our trading bots just closed a signal for OMGU...
# 12  Our eyes on $ADA... • Price (#USD): $ 1.495000...
# 13  Wealth of world's 10 richest men doubled in pa...
# 14  #Bitcoin attacking the H1 EMA30 again.\nIt has...
#
#                                        Cleaned Tweets  Subjetivity  Polarity  \
# 0   [NEW] Monthly Skeptics Discussion - January 20...     0.454545  0.136364
# 1   Bitcoin attacking the H1 EMA30 again.It has be...     0.393750 -0.156250
# 2   @WatcherGuru Someone please explain in simple ...     0.357143  0.000000
# 3   Our trading bots just closed a signal for BNBE...     0.100000 -0.100000
# 4   Bitcoin attacking the H1 EMA30 again.It has be...     0.393750 -0.156250
# 5   Our trading bots just closed a signal for OMGB...     0.100000 -0.100000
# 6   @BluesparrowC @CoinMarketCap @BlueSparrowETH  ...     0.300000  0.200000
# 7   💰 CRYPTO BUYS (01/17/2022 01:01)- Internet Com...     0.000000  0.000000
# 8   💰 CRYPTO BUYS (01/17/2022 01:01)- THORChain: $...     0.000000  0.000000
# 9   Our trading bots just closed a signal for BNBB...     0.100000 -0.100000
# 10  Bitcoin attacking the H1 EMA30 again.It has be...     0.393750 -0.156250
# 11  Our trading bots just closed a signal for OMGU...     0.100000 -0.100000
# 12  Our eyes on $ADA... • Price (): $ 1.49500000  ...     0.000000  0.000000
# 13  Wealth of world's 10 richest men doubled in pa...     0.000000  0.000000
# 14  Bitcoin attacking the H1 EMA30 again.It has be...     0.393750 -0.156250
#
#    Sentiment
# 0   Positive
# 1   Negative
# 2    Neutral
# 3   Negative
# 4   Negative
# 5   Negative
# 6   Positive
# 7    Neutral
# 8    Neutral
# 9   Negative
# 10  Negative
# 11  Negative
# 12   Neutral
# 13   Neutral
# 14  Negative

# %%
ax = sns.relplot(df['Polarity'], df['Subjetivity'], hue = df['Polarity'], palette='RdBu')
ax.fig.set_size_inches(10,6)

norm = plt.Normalize(df['Polarity'].min(), df['Polarity'].max())
sm = plt.cm.ScalarMappable(cmap="RdBu", norm=norm)
sm.set_array([])

plt.show()
# Out:
# /home/edmundotome/anaconda3/envs/Signal-Processing/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#create a barchar to show the count of positive, neutral and negative sentiments
df['Sentiment'].value_counts().plot(kind='bar')
plt.title('Sentiment Analysis Bar Plot')
plt.xlabel('Sentiment')
plt.ylabel('Number of Tweets')
plt.show()

# %%
df['Sentiment'].value_counts()
# Out:
# Positive    503
# Neutral     362
# Negative    135
# Name: Sentiment, dtype: int64

# %%
val_count = list(df['Sentiment'].value_counts())
val_count
# Out:
# [503, 362, 135]

# %%
lst_df = list(df['Sentiment'].value_counts())
lst_df
# Out:
# [503, 362, 135]

# %%
dfs = pd.read_csv("f_sentiments.csv")
  
# updating the column value/data
dfs.loc[9, 'Sentiment'] = 'day 10'
dfs.loc[9, 'Positive'] = lst_df[0]
dfs.loc[9, 'Neutral'] = lst_df[1]
dfs.loc[9, 'Negative'] = lst_df[2]
  
# writing into the file
dfs.to_csv("f_sentiments.csv", index=False)
  
print(dfs)
# Out:
#   Sentiment  Positive  Neutral  Negative
# 0     day 1     540.0    414.0      46.0
# 1     day 2     542.0    412.0      46.0
# 2     day 3     578.0    377.0      45.0
# 3     day 4     530.0    382.0      88.0
# 4     day 5     601.0    351.0      48.0
# 5     day 6     603.0    348.0      49.0
# 6     day 7     516.0    383.0     101.0
# 7     day 8     525.0    375.0     100.0
# 8     day 9     541.0    355.0     104.0
# 9    day 10     503.0    362.0     135.0
