# %% [markdown]
# # 6th Oct

# %%
import tweepy
import pandas as pd
import numpy as np
import re
import seaborn as sns
import matplotlib.pyplot as plt
from textblob import TextBlob
from tweepy.auth import OAuthHandler

# %%
path = r'/home/edmundotome/Documents/Github Projects/LogAPItwitter.csv'
log = pd.read_csv(path)

# %%
consumerKey = log['API Key'][0]
consumerSecret = log['API Key Secret'][0]

accessToken = log['Access Token'][0]
accessTokenSecret = log['Access Token Secret'][0]

# %%
auth = OAuthHandler(consumerKey, consumerSecret)
auth.set_access_token(accessToken, accessTokenSecret)

api = tweepy.API(auth, wait_on_rate_limit=True)

# %%
#gather 1000 tweets about Bitcoin and filter out any retweets 'RT'
search_term = '#bitcoin -filter:retweets'

#create a cursor object
tweets = tweepy.Cursor(api.search, q=search_term, lang='en', since='2021-10-07', tweet_mode='extended').items(1000)

#store tweets in a variable and get the full text
all_tweets = [tweet.full_text for tweet in tweets]

# %%
#create a dataframe to store the tweets with a column called 'tweets'
df = pd.DataFrame(all_tweets, columns=['Tweets'])
#show the first 5 rows of data
df.head(10)
# Out:
#                                               Tweets
# 0  @RMoonOfficial #Bitcoin #Etherum #TCT \nGood p...
# 1  @lina_octave Before this just when I zoomed ou...
# 2  I´m giving 0.1 #btc #bitcoin to the first 1000...
# 3  XRP is getting ready to fly to the moon! #xrp ...
# 4  We just know that #XRP will Go to the moon #cr...
# 5  @ZoroToken good project \n#ZoroCrypto #binance...
# 6  @pierre_crypt0 I never pay taxes on #Bitcoin b...
# 7  @AirdropStario very clear project, the team is...
# 8  @JPowRobbedYou The confidence level in #Bitcoi...
# 9  The third largest whale just unloaded 1,500 #B...

# %%
#create a function to clean the tweets 
def cleanTwt(twt):
  twt = re.sub('#bitcoin', 'bitcoin', twt) #removes the '#' from bitcoin
  twt = re.sub('#Bitcoin', 'Bitcoin', twt)
  twt = re.sub('#BTC', 'Bitcoin', twt)
  twt = re.sub('#[A-Za-z0-9]+', '', twt) #removes any strings with a '#'
  twt = re.sub('\\n', '', twt) #removes the '\n' string
  twt = re.sub('https?:\/\/\S+', '', twt) #removes any hyperlinks
  return twt

# %%
#clean the tweets
df['Cleaned Tweets'] = df['Tweets'].apply(cleanTwt)
#show the dataset
df.head()
# Out:
#                                               Tweets  \
# 0  @RMoonOfficial #Bitcoin #Etherum #TCT \nGood p...
# 1  @lina_octave Before this just when I zoomed ou...
# 2  I´m giving 0.1 #btc #bitcoin to the first 1000...
# 3  XRP is getting ready to fly to the moon! #xrp ...
# 4  We just know that #XRP will Go to the moon #cr...
#
#                                       Cleaned Tweets
# 0              @RMoonOfficial Bitcoin   Good project
# 1  @lina_octave Before this just when I zoomed ou...
# 2  I´m giving 0.1  bitcoin to the first 1000 peop...
# 3  XRP is getting ready to fly to the moon!   bit...
# 4  We just know that  will Go to the moon   bitco...

# %%
#create a function to get subjetivity
def getSubjectivity(twt):
  return TextBlob(twt).sentiment.subjectivity
#create a function to get polarity
def getPolarity(twt):
  return TextBlob(twt).sentiment.polarity

#create two new columns called 'Subjetivity' and 'Polarity'
df['Subjetivity'] = df['Cleaned Tweets'].apply(getSubjectivity)

df['Polarity'] = df['Cleaned Tweets'].apply(getPolarity)

df.head(15)
# Out:
#                                                Tweets  \
# 0   @RMoonOfficial #Bitcoin #Etherum #TCT \nGood p...
# 1   @lina_octave Before this just when I zoomed ou...
# 2   I´m giving 0.1 #btc #bitcoin to the first 1000...
# 3   XRP is getting ready to fly to the moon! #xrp ...
# 4   We just know that #XRP will Go to the moon #cr...
# 5   @ZoroToken good project \n#ZoroCrypto #binance...
# 6   @pierre_crypt0 I never pay taxes on #Bitcoin b...
# 7   @AirdropStario very clear project, the team is...
# 8   @JPowRobbedYou The confidence level in #Bitcoi...
# 9   The third largest whale just unloaded 1,500 #B...
# 10  People rave about #bitcoin's scarcity; why don...
# 11  BurntToast53 found #bitcoin in a User vault at...
# 12  TRTL Rises UP! %40\nW-TRTL swap is underway.\n...
# 13  This zesty faucet from @_bitcoiner is making m...
# 14  Comedy hour starts when Jim starts typing. 😂 #...
#
#                                        Cleaned Tweets  Subjetivity  Polarity
# 0               @RMoonOfficial Bitcoin   Good project     0.600000  0.700000
# 1   @lina_octave Before this just when I zoomed ou...     0.000000  0.000000
# 2   I´m giving 0.1  bitcoin to the first 1000 peop...     0.333333  0.390625
# 3   XRP is getting ready to fly to the moon!   bit...     0.700000  0.600000
# 4   We just know that  will Go to the moon   bitco...     0.000000  0.000000
# 5      @ZoroToken good project       Bitcoin              0.600000  0.700000
# 6   @pierre_crypt0 I never pay taxes on Bitcoin be...     0.000000  0.000000
# 7   @AirdropStario very clear project, the team is...     0.544167  0.348333
# 8   @JPowRobbedYou The confidence level in Bitcoin...     0.400000  0.000000
# 9   The third largest whale just unloaded 1,500 Bi...     0.000000  0.000000
# 10  People rave about bitcoin's scarcity; why don'...     0.410417  0.127083
# 11  BurntToast53 found bitcoin in a User vault at ...     1.000000  1.000000
# 12  TRTL Rises UP! %40W-TRTL swap is underway.Swap...     0.300000  0.100000
# 13  This zesty faucet from @_bitcoiner is making m...     0.800000  0.400000
# 14  Comedy hour starts when Jim starts typing. 😂 B...     0.000000  0.000000

# %%
#create a function to get sentiment text 
def getSentiment(score):
  if score < 0:
    return 'Negative'
  elif score == 0:
    return 'Neutral'
  else:
    return 'Positive'

# %%
#create a column to store the text sentiment
df['Sentiment'] = df['Polarity'].apply(getSentiment)

df.head(15)
# Out:
#                                                Tweets  \
# 0   @RMoonOfficial #Bitcoin #Etherum #TCT \nGood p...
# 1   @lina_octave Before this just when I zoomed ou...
# 2   I´m giving 0.1 #btc #bitcoin to the first 1000...
# 3   XRP is getting ready to fly to the moon! #xrp ...
# 4   We just know that #XRP will Go to the moon #cr...
# 5   @ZoroToken good project \n#ZoroCrypto #binance...
# 6   @pierre_crypt0 I never pay taxes on #Bitcoin b...
# 7   @AirdropStario very clear project, the team is...
# 8   @JPowRobbedYou The confidence level in #Bitcoi...
# 9   The third largest whale just unloaded 1,500 #B...
# 10  People rave about #bitcoin's scarcity; why don...
# 11  BurntToast53 found #bitcoin in a User vault at...
# 12  TRTL Rises UP! %40\nW-TRTL swap is underway.\n...
# 13  This zesty faucet from @_bitcoiner is making m...
# 14  Comedy hour starts when Jim starts typing. 😂 #...
#
#                                        Cleaned Tweets  Subjetivity  Polarity  \
# 0               @RMoonOfficial Bitcoin   Good project     0.600000  0.700000
# 1   @lina_octave Before this just when I zoomed ou...     0.000000  0.000000
# 2   I´m giving 0.1  bitcoin to the first 1000 peop...     0.333333  0.390625
# 3   XRP is getting ready to fly to the moon!   bit...     0.700000  0.600000
# 4   We just know that  will Go to the moon   bitco...     0.000000  0.000000
# 5      @ZoroToken good project       Bitcoin              0.600000  0.700000
# 6   @pierre_crypt0 I never pay taxes on Bitcoin be...     0.000000  0.000000
# 7   @AirdropStario very clear project, the team is...     0.544167  0.348333
# 8   @JPowRobbedYou The confidence level in Bitcoin...     0.400000  0.000000
# 9   The third largest whale just unloaded 1,500 Bi...     0.000000  0.000000
# 10  People rave about bitcoin's scarcity; why don'...     0.410417  0.127083
# 11  BurntToast53 found bitcoin in a User vault at ...     1.000000  1.000000
# 12  TRTL Rises UP! %40W-TRTL swap is underway.Swap...     0.300000  0.100000
# 13  This zesty faucet from @_bitcoiner is making m...     0.800000  0.400000
# 14  Comedy hour starts when Jim starts typing. 😂 B...     0.000000  0.000000
#
#    Sentiment
# 0   Positive
# 1    Neutral
# 2   Positive
# 3   Positive
# 4    Neutral
# 5   Positive
# 6    Neutral
# 7   Positive
# 8    Neutral
# 9    Neutral
# 10  Positive
# 11  Positive
# 12  Positive
# 13  Positive
# 14   Neutral

# %%
ax = sns.relplot(df['Polarity'], df['Subjetivity'], hue = df['Polarity'], palette='RdBu')
ax.fig.set_size_inches(10,6)

norm = plt.Normalize(df['Polarity'].min(), df['Polarity'].max())
sm = plt.cm.ScalarMappable(cmap="RdBu", norm=norm)
sm.set_array([])

plt.show()
# Out:
# /home/edmundotome/anaconda3/envs/Signal-Processing/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#create a barchar to show the count of positive, neutral and negative sentiments
df['Sentiment'].value_counts().plot(kind='bar')
plt.title('Sentiment Analysis Bar Plot')
plt.xlabel('Sentiment')
plt.ylabel('Number of Tweets')
plt.show()

# %%
df['Sentiment'].value_counts()
# Out:
# Neutral     493
# Positive    362
# Negative    145
# Name: Sentiment, dtype: int64

# %%
val_count = list(df['Sentiment'].value_counts())
val_count
# Out:
# [493, 362, 145]

# %%
lst_df = list(df['Sentiment'].value_counts())
lst_df
# Out:
# [493, 362, 145]

# %%
dfs = pd.read_csv("r_sentiments.csv")
  
# updating the column value/data
dfs.loc[9, 'Sentiment'] = 'day 9'
dfs.loc[9, 'Positive'] = lst_df[0]
dfs.loc[9, 'Neutral'] = lst_df[1]
dfs.loc[9, 'Negative'] = lst_df[2]
  
# writing into the file
dfs.to_csv("r_sentiments.csv", index=False)
  
print(dfs)
# Out:
#   Sentiment  Positive  Neutral  Negative
# 0     day 1     494.0    372.0     134.0
# 1     day 2     494.0    388.0     118.0
# 2     day 3     487.0    416.0      97.0
# 3     day 4     495.0    422.0      83.0
# 4     day 5     492.0    360.0     148.0
# 5     day 6     491.0    351.0     158.0
# 6     day 7     465.0    305.0     230.0
# 7     day 8     450.0    298.0     252.0
# 8     day 9     451.0    284.0     265.0
# 9     day 9     493.0    362.0     145.0
